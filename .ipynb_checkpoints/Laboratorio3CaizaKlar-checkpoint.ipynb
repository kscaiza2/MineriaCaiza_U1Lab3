# %% [markdown]
# # LABORATORIO 3 CAIZA KLAR

# %% [markdown]
# ## Regresión Lineal

# %%
'''Importamos los modulos necesarios '''
# %matplotlib notebook
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import svm
from sklearn import datasets
import seaborn as sb
from sklearn.metrics import confusion_matrix

# %%
'''Se le asigno default_rng con el fin de obtener una nueva instancia
de un Generador'''
rng = np.random.default_rng()
'''Generador aleatorio de datos, enviamos por parametro para que genere
un total de 100 datos para X y para Y genera los datos y toma el 
resultado de la funcion'''
x = rng.random(1000)
y = 1.6*x + rng.random(1000)

# %%
'''Calcula una regresion lineal mediante minimos cuadrados para dos conjuntos
de datos, devuelve distintos valores como la pendiente de la recta de 
regresion, coeficiente de correlacion y demas'''
slope, intercept, r, p, std_err = stats.linregress(x, y)

# %%
'''Funcion auxiliar que utiliza la pendiente y la interseccion con el fin
de devolver un nuevo valor'''
def fitted_value(x):
 return slope * x + intercept

# %%
'''Calcular los valores ajustados para el eje Y '''
new_values = list(map(fitted_value, x))

# %%
'''Generamos el grafico de dispersion original'''
plt.plot(x, y, 'o', label='original data')
'''Generamos la grafica de la linea divisoria o dispersion original'''
plt.plot(x, new_values, 'r', label='fitted line')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
'''Procecdemos a imprimir los datos obtenidos'''
print(x,y)
# Out:
# [0.44490981 0.91102788 0.52187356 0.70743728 0.23355922 0.40645845
#  0.73898169 0.81262721 0.7503826  0.54007995 0.78026043 0.53644887
#  0.58853149 0.3953924  0.78293159 0.65395956 0.90334158 0.88727201
#  0.4609254  0.28939419 0.31297748 0.42607944 0.06227528 0.68646982
#  0.90249547 0.59508254 0.04951789 0.2925959  0.84031752 0.39688159
#  0.55551349 0.87564851 0.63710679 0.93195465 0.93129641 0.08376851
#  0.29057795 0.91159978 0.23095436 0.7366478  0.12240087 0.88172671
#  0.09761793 0.51740829 0.54242831 0.5850565  0.36907282 0.42529948
#  0.69703208 0.96795469 0.06539566 0.35110268 0.79892799 0.74878819
#  0.06123256 0.53056442 0.56257781 0.41065735 0.23087066 0.38482893
#  0.63217219 0.26140093 0.38903589 0.07256931 0.32392872 0.91473775
#  0.62887876 0.3801044  0.75453715 0.75433823 0.70957682 0.15380579
#  0.80701132 0.10499894 0.61806966 0.98469511 0.56093733 0.76866646
#  0.55425192 0.55098094 0.3625371  0.8513689  0.90323681 0.85224425
# ...

# %%
'''Verificamos cuantos datos se tienen en cada una de las variables creadas.'''
print(x.shape[0])
print(y.shape[0])
# Out:
# 1000
# 1000

# %%
'''
Division de los datos usando la función 
train_test_split de sklearn. Usaremos las 
variables X,y, con un tamaño de entrenamiento 
del 30% y una selección random de posición 109'''

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=109)

# %%
'''Verificar la cantidad de datos que se usó para el entrenamiento.'''
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (700,) (300,) (700,) (300,)

# %%
'''Definimos el algoritmo en funcion del modelo de regresion lineal'''
LinReg_multiple = LinearRegression()
